# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import date, timedelta

# %%
def find_sheet_name(sheet_names):
    filtered_sheet_names = list(
        filter(
            lambda x: (
                "vdt" in x.lower()
                or "vđt" in x.lower()
                or "von" in x.lower()
                or "vnsnn" in x.lower()
            )
            and "nsnn" in x.lower()
            and ("quý" not in x.lower())
            and ("quy" not in x.lower())
            and ("txh" not in x.lower()),
            sheet_names,
        )
    )

    if len(filtered_sheet_names) == 1:
        return filtered_sheet_names[0]

    filtered_sheet_names = list(
        filter(
            lambda x: (
                "vdt" in x.lower()
                or "vđt" in x.lower()
                or "von" in x.lower()
                or "vnsnn" in x.lower()
            )
            and "thực hiện" in x.lower()
            and ("quý" not in x.lower())
            and ("quy" not in x.lower())
            and ("txh" not in x.lower()),
            sheet_names,
        )
    )

    if len(filtered_sheet_names) == 1:
        return filtered_sheet_names[0]

    filtered_sheet_names = list(
        filter(
            lambda x: (
                "vdt" in x.lower()
                or "vđt" in x.lower()
                or "von" in x.lower()
                or "vnsnn" in x.lower()
            )
            and ("quý" not in x.lower())
            and ("quy" not in x.lower())
            and ("txh" not in x.lower()),
            sheet_names,
        )
    )

    if len(filtered_sheet_names) == 1:
        return filtered_sheet_names[0]

    filtered_sheet_names = list(
        filter(
            lambda x: (
                "vdt" in x.lower()
                or "vđt" in x.lower()
                or "von" in x.lower()
                or "vnsnn" in x.lower()
                or "dtu" in x.lower()
            )
            and ("quý" not in x.lower())
            and ("quy" not in x.lower())
            and ("txh" not in x.lower()),
            sheet_names,
        )
    )

    if len(filtered_sheet_names) == 1:
        return filtered_sheet_names[0]

    if len(sheet_names) == 43:
        return "20"
    
    if len(sheet_names) == 13:
        return "Sheet1"

    raise RuntimeError(sheet_names, filtered_sheet_names)

# %%
en_to_vn = {
    "TOTAL": "TỔNG SỐ",
    "Central": "Trung ương",
    "Of which:": "Trong đó:",
    "Ministry of Transport": "Bộ Giao thông vận tải",
    "Ministry of Health": "Bộ Y tế",
    "Ministry of Agriculture & Rural Development": "Bộ NN và PTNT",
    "Ministry of Education & Training": "Bộ Giáo dục - Đào tạo",
    "Ministry of Natural Resources & Environment": "Bộ Tài nguyên và Môi trường",
    "Ministry of Culture, Sports & Tourism": "Bộ Văn hóa, Thể thao và Du lịch",
    "Ministry of Industry & Trade": "Bộ Công thương",
    "Ministry of Construction": "Bộ Xây dựng",
    "Ministry of Science & Technology": "Bộ Khoa học và Công nghệ",
    "Ministry of Information & Communications": "Bộ Thông tin và Truyền thông",
    "Local": "Địa phương",
    "Provincial level": "Vốn ngân sách NN cấp tỉnh",
    "District level": "Vốn ngân sách NN cấp huyện",
    "Commune level": "Vốn ngân sách NN cấp xã",
    "Selected localities": "Phân theo một số tỉnh, thành phố",
    "Ha Noi": "Hà Nội",
    "Ho Chi Minh city": "TP. Hồ Chí Minh",
    "Quang Ninh": "Quảng Ninh",
    "Binh Duong": "Bình Dương",
    "Hai Phong": "Hải Phòng",
    "Thanh Hoa": "Thanh Hóa",
    "Ba Ria - Vung Tau": "Bà Rịa - Vũng Tàu",
    "Nghe An": "Nghệ An",
    "Binh Dinh": "Bình Định",
    "Vinh Phuc": "Vĩnh Phúc",
    "Bac Ninh": "Bắc Ninh",
    "Dong Nai": "Đồng Nai",
    "Quang Nam": "Quảng Nam",
    "Bac Giang": "Bắc Giang",
    "Quang Ngai": "Quảng Ngãi",
    "Tien Giang": "Tiền Giang",
    "Thue Thien - Hue": "Thừa Thiên - Huế",
    "Thai Nguyen": "Thái Nguyên",
    "Tay Ninh": "Tây Ninh",
    "Binh Thuan": "Bình Thuận",
    "Binh Phuoc": "Bình Phước",
    "Long An": "Long An",
    "Thua Thien - Hue": "Thừa Thiên - Huế",
    "Phu Yen": "Phú Yên",
    "An Giang": "An Giang",
    "Ha Tinh": "Hà Tĩnh",
    "Thai Binh": "Thái Bình",
    "Kien Giang": "Kiên Giang",
}

# %%
def get_vdt(xl, sheet_name, date):
    df = xl.parse(sheet_name)

    df = df.dropna(axis=1, how="all")

    df[df.columns[0]] = (
        df[df.columns[0]]
        .replace(r"\s+", " ", regex=True)
        .replace(r"\n", " ", regex=True)
        .str.strip()
    )
    df[df.columns[1]] = (
        df[df.columns[1]]
        .replace(r"\s+", " ", regex=True)
        .replace(r"\n", " ", regex=True)
        .str.strip()
    )

    if (
        len(
            df[df.columns[1]][
                (df[df.columns[1]] == "Trung ương") | (df[df.columns[1]] == "Central")
            ].index
        )
        > 0
    ):
        df[df.columns[1]] = df[df.columns[1]].fillna(df[df.columns[0]])
        df = df.drop(columns=[df.columns[0]])
    df = df.reset_index(drop=True)

    df = df.drop(
        list(
            range(
                df[df.columns[0]][
                    (df[df.columns[0]] == "TỔNG SỐ") | ((df[df.columns[0]] == "TOTAL"))
                ].index[0]
            )
        )
    )
    df = df.reset_index(drop=True)

    if len(df[df.columns[0]][df[df.columns[0]] == "TOTAL"].index) > 0:
        df[df.columns[0]] = df[df.columns[0]].map(en_to_vn)

    if len(df.columns) == 6:
        df.columns = [
            "Phân Loại",
            "Total-Pre-Month",
            "Total-M",
            "Total-YOY",
            "YOP",
            "YTD-YOY",
        ]

        df["YTD-YOY"] = df["YTD-YOY"] - 100
    elif len(df.columns) == 5 and int(date.split("-")[1]) == 1:
        df.columns = ["Phân Loại", "Total-Pre-Month", "Total-M", "YOP", "YTD-YOY"]
        df["Total-YOY"] = df["Total-M"]

        df["YTD-YOY"] = df["YTD-YOY"] - 100
    else:
        raise RuntimeError

    df = df[df["Total-M"].notna()].replace("-", None)
    df = df[df["Total-YOY"].notna()].replace("-", None)
    df = df[df["YOP"].notna()].replace("-", None)
    df = df[df["YTD-YOY"].notna()].replace("-", None)

    df["Total-Pre-Month"] = df["Total-Pre-Month"].astype(float)
    df["Total-M"] = df["Total-M"].astype(float)
    df["Total-YOY"] = df["Total-YOY"].astype(float)
    df["YOP"] = df["YOP"].astype(float)
    df["YTD-YOY"] = df["YTD-YOY"].astype(float)

    df["MOM"] = 100 * (df["Total-M"] / df["Total-Pre-Month"]) - 100

    df["Date"] = date
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=False)

    df["Month"] = df["Date"].dt.strftime("%Y-%m")

    df["PreMonth"] = (
        df["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )

    df["PreYearMonth"] = (
        df["Date"]
        .apply(lambda x: x.replace(year=x.year - 1, day=1))
        .dt.strftime("%Y-%m")
    )

    return df


xl = pd.ExcelFile("../datas/2024-01-29-02-Bieu-T1-2024-1.xlsx")

get_vdt(xl, find_sheet_name(xl.sheet_names), "2024-01-29")
# Out:
#                           Phân Loại  Total-Pre-Month    Total-M       YOP  \
# 0                           TỔNG SỐ       703197.055  31118.628  4.425307
# 1                        Trung ương       117792.382   4662.100  3.957896
# 3             Bộ Giao thông vận tải        59664.281   3040.410  5.095863
# 4                     Bộ NN và PTNT        10135.410    305.620  3.015369
# 5            Bộ Giáo dục và Đào tạo         1506.919     42.720  2.834923
# 6   Bộ Văn hóa, Thể thao và Du lịch         1064.160     37.220  3.497594
# 7                    Bộ Công Thương         1057.700     35.320  3.339321
# 8                           Bộ Y tế         1254.720     33.120  2.639633
# 9       Bộ Tài nguyên và Môi trường         1116.160     27.920  2.501433
# 10                      Bộ Xây dựng          324.170     15.940  4.917173
# 11     Bộ Thông tin và Truyền thông          453.700     13.840  3.050474
# 12         Bộ Khoa học và Công nghệ          257.880      9.670  3.749806
# 13                       Địa phương       585404.673  26456.528  4.519357
# 14        Vốn ngân sách NN cấp tỉnh       417377.603  17388.024  4.166018
# 15       Vốn ngân sách NN cấp huyện       148198.165   7892.160  5.325410
# 16          Vốn ngân sách NN cấp xã        19828.905   1176.344  5.932471
# 18                           Hà Nội        77838.357   3856.891  4.955001
# 19                  TP. Hồ Chí Minh        74395.128   1530.690  2.057514
# 20                       Quảng Ninh        22000.000   1139.268  5.178491
# 21                        Hải Phòng        17722.179   1053.163  5.942627
# 22                Bà Rịa - Vũng Tàu        19921.061   1009.364  5.066818
# 23                         Hòa Bình        19972.740    854.063  4.276143
# 24                         Đồng Nai        17120.470    823.581  4.810505
# 25                       Bình Dương        15023.119    669.257  4.454847
# 26                          Đắk Lắk        12115.663    589.432  4.865041
# 27                          Nghệ An         8311.253    567.080  6.823039
# 28                        Thanh Hóa         9076.670    528.368  5.821166
# 29                         Nam Định         8827.378    514.204  5.825105
# 30                         An Giang         7776.625    464.162  5.968682
# 31                        Thái Bình         8029.238    449.636  5.599983
# 32                        Ninh Bình         6400.399    437.008  6.827824
# 33                        Vĩnh Phúc         6459.903    426.241  6.598257
# 34                      Thái Nguyên         6745.840    424.610  6.294398
# 35                        Bắc Giang         6501.677    424.468  6.528593
# 36                          Phú Thọ         9049.385    418.500  4.624624
# 37                        Quảng Nam         7986.265    414.061  5.184664
# 38                         Hưng Yên         6937.686    383.840  5.532680
# 39                          Lào Cai         5975.828    383.730  6.421370
#
#       YTD-YOY  Total-YOY        MOM       Date    Month PreMonth PreYearMonth
# 0   12.494573  31118.628 -95.574693 2024-01-29  2024-01  2023-12      2023-01
# 1    3.733157   4662.100 -96.042104 2024-01-29  2024-01  2023-12      2023-01
# 3   -5.177130   3040.410 -94.904137 2024-01-29  2024-01  2023-12      2023-01
# 4   13.058597    305.620 -96.984631 2024-01-29  2024-01  2023-12      2023-01
# 5   -4.258180     42.720 -97.165077 2024-01-29  2024-01  2023-12      2023-01
# 6  -29.800075     37.220 -96.502406 2024-01-29  2024-01  2023-12      2023-01
# 7   18.722689     35.320 -96.660679 2024-01-29  2024-01  2023-12      2023-01
# 8  -12.427287     33.120 -97.360367 2024-01-29  2024-01  2023-12      2023-01
# 9   -8.519004     27.920 -97.498567 2024-01-29  2024-01  2023-12      2023-01
# 10 -26.237853     15.940 -95.082827 2024-01-29  2024-01  2023-12      2023-01
# 11   8.463950     13.840 -96.949526 2024-01-29  2024-01  2023-12      2023-01
# 12   5.914567      9.670 -96.250194 2024-01-29  2024-01  2023-12      2023-01
# 13  14.194184  26456.528 -95.480643 2024-01-29  2024-01  2023-12      2023-01
# 14  11.083340  17388.024 -95.833982 2024-01-29  2024-01  2023-12      2023-01
# 15  20.816311   7892.160 -94.674590 2024-01-29  2024-01  2023-12      2023-01
# 16  19.727232   1176.344 -94.067529 2024-01-29  2024-01  2023-12      2023-01
# 18  56.058704   3856.891 -95.044999 2024-01-29  2024-01  2023-12      2023-01
# 19  20.382692   1530.690 -97.942486 2024-01-29  2024-01  2023-12      2023-01
# 20  42.179768   1139.268 -94.821509 2024-01-29  2024-01  2023-12      2023-01
# 21   3.486961   1053.163 -94.057373 2024-01-29  2024-01  2023-12      2023-01
# 22  48.351671   1009.364 -94.933182 2024-01-29  2024-01  2023-12      2023-01
# 23  12.928575    854.063 -95.723857 2024-01-29  2024-01  2023-12      2023-01
# 24   6.937184    823.581 -95.189495 2024-01-29  2024-01  2023-12      2023-01
# 25  24.497180    669.257 -95.545153 2024-01-29  2024-01  2023-12      2023-01
# 26  11.786862    589.432 -95.134959 2024-01-29  2024-01  2023-12      2023-01
# 27  36.080149    567.080 -93.176961 2024-01-29  2024-01  2023-12      2023-01
# 28   2.063019    528.368 -94.178834 2024-01-29  2024-01  2023-12      2023-01
# 29  11.744368    514.204 -94.174895 2024-01-29  2024-01  2023-12      2023-01
# 30  21.027120    464.162 -94.031318 2024-01-29  2024-01  2023-12      2023-01
# 31   4.980575    449.636 -94.400017 2024-01-29  2024-01  2023-12      2023-01
# 32  -3.482943    437.008 -93.172176 2024-01-29  2024-01  2023-12      2023-01
# 33 -12.593381    426.241 -93.401743 2024-01-29  2024-01  2023-12      2023-01
# 34  57.598590    424.610 -93.705602 2024-01-29  2024-01  2023-12      2023-01
# 35  19.206131    424.468 -93.471407 2024-01-29  2024-01  2023-12      2023-01
# 36   3.167755    418.500 -95.375376 2024-01-29  2024-01  2023-12      2023-01
# 37   9.468995    414.061 -94.815336 2024-01-29  2024-01  2023-12      2023-01
# 38  53.015746    383.840 -94.467320 2024-01-29  2024-01  2023-12      2023-01
# 39  10.180490    383.730 -93.578630 2024-01-29  2024-01  2023-12      2023-01

# %%
import os
import contextlib

dfs_vdt_origin = []
for file_name in sorted(
    os.listdir("../datas"),
    key=lambda filename: f"{filename.split('-')[0]}-{filename.split('-')[1]}-{filename.split('-')[2]}",
    reverse=True,
):
    if file_name.startswith(".~"):
        continue

    try:
        file_path = os.path.join("../datas", file_name)

        year = int(file_name.split("-")[0])
        month = int(file_name.split("-")[1])
        day = int(file_name.split("-")[2])

        if year < 2012:
            continue

        xl = pd.ExcelFile(file_path)

        df_xk = get_vdt(xl, find_sheet_name(xl.sheet_names), f"{year}-{month}-{day}")

        dfs_vdt_origin.append(df_xk)
    except Exception as e:
        print(file_name)
        raise e

# %%
dfs_vdt = pd.concat(dfs_vdt_origin, ignore_index=True, axis=0)
dfs_vdt["Date"] = pd.to_datetime(dfs_vdt["Date"], dayfirst=False)
dfs_vdt
# Out:
#                    Phân Loại  Total-Pre-Month      Total-M     Total-YOY  \
# 0                    TỔNG SỐ      53220.56763  57570.65968  301478.74553
# 1                 Trung ương       9456.40000  10123.10000   51875.53000
# 2      Bộ Giao thông vận tải       5662.42000   5978.21000   31835.42000
# 3              Bộ NN và PTNT        987.52000   1061.62000    5079.56000
# 4     Bộ Giáo dục và Đào tạo         97.52000    119.27000     503.27000
# ...                      ...              ...          ...           ...
# 5551               Khánh Hoà       1898.90000     85.00000      85.00000
# 5552                Hưng Yên       1106.50000     83.60000      83.60000
# 5553              Ninh Thuận        870.50000     66.00000      66.00000
# 5554                 Đắk Lắk       1136.90000     57.00000      57.00000
# 5555                  Sơn La       1144.40000     54.50000      54.50000
#
#             YOP    YTD-YOY        MOM       Date    Month PreMonth  \
# 0     40.592353   2.280699   8.173705 2024-07-29  2024-07  2024-06
# 1     44.949924  -3.715459   7.050252 2024-07-29  2024-07  2024-06
# 2     50.882711 -20.942479   5.576944 2024-07-29  2024-07  2024-06
# 3     50.116966  37.558664   7.503645 2024-07-29  2024-07  2024-06
# 4     24.431543   6.638556  22.303117 2024-07-29  2024-07  2024-06
# ...         ...        ...        ...        ...      ...      ...
# 5551   4.476276 -18.582375 -95.523724 2012-01-30  2012-01  2011-12
# 5552   7.555355   6.091371 -92.444645 2012-01-30  2012-01  2011-12
# 5553   7.581850   3.125000 -92.418150 2012-01-30  2012-01  2011-12
# 5554   5.013634 -37.362637 -94.986366 2012-01-30  2012-01  2011-12
# 5555   4.762321 -71.673597 -95.237679 2012-01-30  2012-01  2011-12
#
#      PreYearMonth
# 0         2023-07
# 1         2023-07
# 2         2023-07
# 3         2023-07
# 4         2023-07
# ...           ...
# 5551      2011-01
# 5552      2011-01
# 5553      2011-01
# 5554      2011-01
# 5555      2011-01
#
# [5556 rows x 11 columns]

# %%
convert_phan_loai = {
    "An Giang": "An Giang",
    "Bà Rịa - Vũng Tàu": "Bà Rịa - Vũng Tàu",
    "Bà Rịa-Vũng Tàu": "Bà Rịa - Vũng Tàu",
    "Bình Dương": "Bình Dương",
    "Bình Phước": "Bình Phước",
    "Bình Định": "Bình Định",
    "Bạc Liêu": "Bạc Liêu",
    "Bắc Giang": "Bắc Giang",
    "Bắc Ninh": "Bắc Ninh",
    "Bến Tre": "Bến Tre",
    "Bộ Công Thương": "Bộ Công Thương",
    "Bộ Công thương": "Bộ Công Thương",
    "Bộ Giao thông Vận tải": "Bộ Giao thông Vận tải",
    "Bộ Giao thông vận tải": "Bộ Giao thông Vận tải",
    "Bộ Giáo dục - Đào tạo": "Bộ Giáo dục - Đào tạo",
    "Bộ Giáo dục và Đào tạo": "Bộ Giáo dục - Đào tạo",
    "Bộ Khoa học và Công nghệ": "Bộ Khoa học và Công nghệ",
    "Bộ NN và PTNT": "Bộ NN và PTNT",
    "Bộ Thông tin và Truyền thông": "Bộ Thông tin và Truyền thông",
    "Bộ Tài nguyên và Môi trường": "Bộ Tài nguyên và Môi trường",
    "Bộ Văn hoá, Thể thao và Du lịch": "Bộ Văn hoá, Thể thao và Du lịch",
    "Bộ Văn hoá,Thể thao và Du lịch": "Bộ Văn hoá, Thể thao và Du lịch",
    "Bộ Văn hóa, Thể thao và Du lịch": "Bộ Văn hoá, Thể thao và Du lịch",
    "Bộ Xây dựng": "Bộ Xây dựng",
    "Bộ Y tế": "Bộ Y tế",
    "Cà Mau": "Cà Mau",
    "Cần Thơ": "Cần Thơ",
    "Hà Tĩnh": "Hà Tĩnh",
    "Hà Giang": "Hà Giang",
    "Hà Nam": "Hà Nam",
    "Hà Nội": "Hà Nội",
    "Hà Tĩnh": "Hà Tĩnh",
    "Hòa Bình": "Hòa Bình",
    "Hưng Yên": "Hưng Yên",
    "Hải Dương": "Hải Dương",
    "Hải Phòng": "Hải Phòng",
    "Hậu Giang": "Hậu Giang",
    "Khánh Hòa": "Khánh Hòa",
    "Khánh Hoà": "Khánh Hòa",
    "Khánh Hòa": "Khánh Hòa",
    "Kiên Giang": "Kiên Giang",
    "Lai Châu": "Lai Châu",
    "Long An": "Long An",
    "Lào Cai": "Lào Cai",
    "Lâm Đồng": "Lâm Đồng",
    "Nam Định": "Nam Định",
    "Nghệ An": "Nghệ An",
    "Ninh Bình": "Ninh Bình",
    "Ninh Thuận": "Ninh Thuận",
    "Phú Thọ": "Phú Thọ",
    "Phú Yên": "Phú Yên",
    "Quảng Bình": "Quảng Bình",
    "Quảng Nam": "Quảng Nam",
    "Quảng Ngãi": "Quảng Ngãi",
    "Quảng Ninh": "Quảng Ninh",
    "Quảng Trị": "Quảng Trị",
    "Sóc Trăng": "Sóc Trăng",
    "Sơn La": "Sơn La",
    "TP. Hồ Chí Minh": "TP. Hồ Chí Minh",
    "Thanh Hóa": "Thanh Hóa",
    "Thái Bình": "Thái Bình",
    "Thái Nguyên": "Thái Nguyên",
    "Thừa Thiên - Huế": "Thừa Thiên - Huế",
    "Thừa Thiên-Huế": "Thừa Thiên - Huế",
    "Tiền Giang": "Tiền Giang",
    "Tp. Hồ Chí Minh": "TP. Hồ Chí Minh",
    "Trung ương": "Trung ương",
    "Trà Vinh": "Trà Vinh",
    "Tây Ninh": "Tây Ninh",
    "TỔNG SỐ": "TỔNG SỐ",
    "Vĩnh Long": "Vĩnh Long",
    "Vĩnh Phúc": "Vĩnh Phúc",
    "Vốn ngân sách NN cấp huyện": "Vốn ngân sách NN cấp huyện",
    "Vốn ngân sách NN cấp tỉnh": "Vốn ngân sách NN cấp tỉnh",
    "Vốn ngân sách NN cấp xã": "Vốn ngân sách NN cấp xã",
    "Điện Biên": "Điện Biên",
    "Đà Nẵng": "Đà Nẵng",
    "Đắk Lắk": "Đắk Lắk",
    "Đắk Lắk": "Đắk Lắk",
    "Đắk Nông": "Đắk Nông",
    "Địa phương": "Địa phương",
    "Đồng Nai": "Đồng Nai",
    "Đồng Tháp": "Đồng Tháp",
}


for pl in dfs_vdt["Phân Loại"].unique().tolist():
    assert pl in convert_phan_loai.keys(), pl


dfs_vdt["Phân Loại"] = dfs_vdt["Phân Loại"].map(convert_phan_loai)
dfs_vdt
# Out:
#                   Phân Loại  Total-Pre-Month      Total-M     Total-YOY  \
# 0                   TỔNG SỐ      53220.56763  57570.65968  301478.74553
# 1                Trung ương       9456.40000  10123.10000   51875.53000
# 2     Bộ Giao thông Vận tải       5662.42000   5978.21000   31835.42000
# 3             Bộ NN và PTNT        987.52000   1061.62000    5079.56000
# 4     Bộ Giáo dục - Đào tạo         97.52000    119.27000     503.27000
# ...                     ...              ...          ...           ...
# 5551            Khánh Hòa       1898.90000     85.00000      85.00000
# 5552               Hưng Yên       1106.50000     83.60000      83.60000
# 5553             Ninh Thuận        870.50000     66.00000      66.00000
# 5554              Đắk Lắk       1136.90000     57.00000      57.00000
# 5555                 Sơn La       1144.40000     54.50000      54.50000
#
#             YOP    YTD-YOY        MOM       Date    Month PreMonth  \
# 0     40.592353   2.280699   8.173705 2024-07-29  2024-07  2024-06
# 1     44.949924  -3.715459   7.050252 2024-07-29  2024-07  2024-06
# 2     50.882711 -20.942479   5.576944 2024-07-29  2024-07  2024-06
# 3     50.116966  37.558664   7.503645 2024-07-29  2024-07  2024-06
# 4     24.431543   6.638556  22.303117 2024-07-29  2024-07  2024-06
# ...         ...        ...        ...        ...      ...      ...
# 5551   4.476276 -18.582375 -95.523724 2012-01-30  2012-01  2011-12
# 5552   7.555355   6.091371 -92.444645 2012-01-30  2012-01  2011-12
# 5553   7.581850   3.125000 -92.418150 2012-01-30  2012-01  2011-12
# 5554   5.013634 -37.362637 -94.986366 2012-01-30  2012-01  2011-12
# 5555   4.762321 -71.673597 -95.237679 2012-01-30  2012-01  2011-12
#
#      PreYearMonth
# 0         2023-07
# 1         2023-07
# 2         2023-07
# 3         2023-07
# 4         2023-07
# ...           ...
# 5551      2011-01
# 5552      2011-01
# 5553      2011-01
# 5554      2011-01
# 5555      2011-01
#
# [5556 rows x 11 columns]

# %%
merge_df = pd.merge(
    left=dfs_vdt,
    right=dfs_vdt,
    left_on=["Phân Loại", "Month"],
    right_on=["Phân Loại", "PreMonth"],
    how="left",
)
merge_df["Merged_Total"] = np.where(
    merge_df["Total-Pre-Month_y"].isna(),
    merge_df["Total-M_x"],
    merge_df["Total-Pre-Month_y"],
)
merge_df = merge_df.drop(
    columns=[
        "Total-Pre-Month_y",
        "Total-M_y",
        "Total-YOY_y",
        "YOP_y",
        "YTD-YOY_y",
        "MOM_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "PreYearMonth_y"
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-Pre-Month_x": "Total-Pre-Month",
        "Total-M_x": "E-Total-M",
        "Total-YOY_x": "Total-YOY",
        "YOP_x": "YOP",
        "YTD-YOY_x": "YTD-YOY",
        "MOM_x": "E-MOM",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "PreYearMonth_x": "PreYearMonth",
        "Merged_Total": "Total-M",
    }
)
merge_df["MOM"] = 100 * (merge_df["Total-M"] / merge_df["Total-Pre-Month"]) - 100
dfs_vdt = merge_df
merge_df[merge_df["Phân Loại"] == "TỔNG SỐ"]
# Out:
#      Phân Loại  Total-Pre-Month    E-Total-M     Total-YOY        YOP  \
# 0      TỔNG SỐ      53220.56763  57570.65968  301478.74553  40.592353
# 38     TỔNG SỐ      48310.36700  53718.11600  244405.63422  33.808228
# 75     TỔNG SỐ      43488.77300  48214.54900  190590.70022  26.619974
# 112    TỔNG SỐ      37878.88600  43955.38000  142842.75822  20.081556
# 149    TỔNG SỐ      28078.11222  36739.87300   97748.36522  13.850160
# ...        ...              ...          ...           ...        ...
# 5396   TỔNG SỐ      16666.80000  18077.20000   72993.60000  36.421735
# 5428   TỔNG SỐ      16377.00000  17064.80000   55314.40000  27.837363
# 5460   TỔNG SỐ      11177.30000  15106.50000   36979.10000  18.977655
# 5491   TỔNG SỐ      10695.30000  11335.10000   22030.40000  11.549182
# 5523   TỔNG SỐ     171173.00000  11244.80000   11244.80000   6.569260
#
#        YTD-YOY      E-MOM       Date    Month PreMonth PreYearMonth  \
# 0     2.280699   8.173705 2024-07-29  2024-07  2024-06      2023-07
# 38    3.459512  11.193765 2024-06-29  2024-06  2024-05      2023-06
# 75    4.951109  10.866657 2024-05-29  2024-05  2024-04      2023-05
# 112   5.944870  16.041903 2024-04-29  2024-04  2024-03      2023-04
# 149   3.741649  30.848800 2024-03-29  2024-03  2024-02      2023-03
# ...        ...        ...        ...      ...      ...          ...
# 5396  4.005563   8.462332 2012-05-29  2012-05  2012-04      2011-05
# 5428  3.824554   4.199792 2012-04-30  2012-04  2012-03      2011-04
# 5460  1.300000  35.153391 2012-03-29  2012-03  2012-02      2011-03
# 5491  1.152930   5.982067 2012-02-29  2012-02  2012-01      2011-02
# 5523 -1.745802 -93.430740 2012-01-30  2012-01  2011-12      2011-01
#
#           Total-M        MOM
# 0     57570.65968   8.173705
# 38    53220.56763  10.163865
# 75    48310.36700  11.086986
# 112   43488.77300  14.810063
# 149   37878.88600  34.905387
# ...           ...        ...
# 5396  18088.20000   8.528332
# 5428  16666.80000   1.769555
# 5460  16377.00000  46.520179
# 5491  11177.30000   4.506652
# 5523  10695.30000 -93.751760
#
# [151 rows x 13 columns]

# %%
merge_df = pd.merge(
    left=dfs_vdt,
    right=dfs_vdt,
    left_on=["Phân Loại", "PreYearMonth"],
    right_on=["Phân Loại", "Month"],
    how="left",
)
merge_df["M-YOY"] = 100 * (merge_df["Total-M_x"] / merge_df["Total-M_y"]) - 100
merge_df = merge_df.drop(
    columns=[
        "Total-Pre-Month_y",
        "E-Total-M_y",
        "Total-YOY_y",
        "YOP_y",
        "YTD-YOY_y",
        "E-MOM_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "PreYearMonth_y",
        "Total-M_y",
        "MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-Pre-Month_x": "Total-Pre-Month",
        "E-Total-M_x": "E-Total-M",
        "Total-YOY_x": "Total-YOY",
        "YOP_x": "YOP",
        "YTD-YOY_x": "YTD-YOY",
        "E-MOM_x": "E-MOM",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "PreYearMonth_x": "PreYearMonth",
        "Total-M_x": "Total-M",
        "MOM_x": "MOM",
    }
)
dfs_vdt = merge_df
merge_df[merge_df["Phân Loại"] == "TỔNG SỐ"]
# Out:
#      Phân Loại  Total-Pre-Month    E-Total-M     Total-YOY        YOP  \
# 0      TỔNG SỐ      53220.56763  57570.65968  301478.74553  40.592353
# 38     TỔNG SỐ      48310.36700  53718.11600  244405.63422  33.808228
# 75     TỔNG SỐ      43488.77300  48214.54900  190590.70022  26.619974
# 112    TỔNG SỐ      37878.88600  43955.38000  142842.75822  20.081556
# 149    TỔNG SỐ      28078.11222  36739.87300   97748.36522  13.850160
# ...        ...              ...          ...           ...        ...
# 5396   TỔNG SỐ      16666.80000  18077.20000   72993.60000  36.421735
# 5428   TỔNG SỐ      16377.00000  17064.80000   55314.40000  27.837363
# 5460   TỔNG SỐ      11177.30000  15106.50000   36979.10000  18.977655
# 5491   TỔNG SỐ      10695.30000  11335.10000   22030.40000  11.549182
# 5523   TỔNG SỐ     171173.00000  11244.80000   11244.80000   6.569260
#
#        YTD-YOY      E-MOM       Date    Month PreMonth PreYearMonth  \
# 0     2.280699   8.173705 2024-07-29  2024-07  2024-06      2023-07
# 38    3.459512  11.193765 2024-06-29  2024-06  2024-05      2023-06
# 75    4.951109  10.866657 2024-05-29  2024-05  2024-04      2023-05
# 112   5.944870  16.041903 2024-04-29  2024-04  2024-03      2023-04
# 149   3.741649  30.848800 2024-03-29  2024-03  2024-02      2023-03
# ...        ...        ...        ...      ...      ...          ...
# 5396  4.005563   8.462332 2012-05-29  2012-05  2012-04      2011-05
# 5428  3.824554   4.199792 2012-04-30  2012-04  2012-03      2011-04
# 5460  1.300000  35.153391 2012-03-29  2012-03  2012-02      2011-03
# 5491  1.152930   5.982067 2012-02-29  2012-02  2012-01      2011-02
# 5523 -1.745802 -93.430740 2012-01-30  2012-01  2011-12      2011-01
#
#           Total-M        MOM     M-YOY
# 0     57570.65968   8.173705 -1.140368
# 38    53220.56763  10.163865 -2.306598
# 75    48310.36700  11.086986  4.532482
# 112   43488.77300  14.810063  8.595397
# 149   37878.88600  34.905387  8.613865
# ...           ...        ...       ...
# 5396  18088.20000   8.528332       NaN
# 5428  16666.80000   1.769555       NaN
# 5460  16377.00000  46.520179       NaN
# 5491  11177.30000   4.506652       NaN
# 5523  10695.30000 -93.751760       NaN
#
# [151 rows x 14 columns]

# %%
dfs_vdt.to_csv("../csv/vdt.csv")
