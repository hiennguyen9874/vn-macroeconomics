# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  35587.417147  335585.942544
# 1              1  Khu vực kinh tế trong nước  10297.449587   93973.607944
# 2              2    Khu vực có vốn đầu tư NN  25289.967560  241612.334600
# 41            41                TỔNG TRỊ GIÁ  34049.626711  299625.132181
# 42            42  Khu vực kinh tế trong nước   9388.747833   83466.453921
# ...          ...                         ...           ...            ...
# 4814        4814  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4815        4815    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4848        4848                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4849        4849  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4850        4850    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     10.093746  14.907858  2024-10-29  2024-10  2024-09   4.516321
# 1     17.741536  20.661341  2024-10-29  2024-10  2024-09   9.678626
# 2      7.257046  12.815584  2024-10-29  2024-10  2024-09   2.550958
# 41    10.699933  15.363247  2024-09-29  2024-09  2024-08  -9.417597
# 42    15.964694  20.727379  2024-09-29  2024-09  2024-08 -13.365525
# ...         ...        ...         ...      ...      ...        ...
# 4814        NaN  13.200000  2014-02-28  2014-02  2014-01  -7.102273
# 4815        NaN  11.800000  2014-02-28  2014-02  2014-01  -6.637168
# 4848 -10.800000 -10.800000  2014-01-29  2014-01  2013-12        NaN
# 4849 -13.800000 -13.800000  2014-01-29  2014-01  2013-12        NaN
# 4850  -9.200000  -9.200000  2014-01-29  2014-01  2013-12        NaN
#
# [388 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  33600.609501  312280.088703
# 1              1  Khu vực kinh tế trong nước  12677.810227  113579.094880
# 2              2    Khu vực có vốn đầu tư NN  20922.799274  198700.993823
# 41            41                TỔNG TRỊ GIÁ  31758.453093  278842.181313
# 42            42  Khu vực kinh tế trong nước  10938.795000  100848.495188
# ...          ...                         ...           ...            ...
# 4805        4805  Khu vực kinh tế trong nước   4650.000000    9059.000000
# 4806        4806    Khu vực có vốn đầu tư NN   6150.000000   11757.000000
# 4842        4842                TỔNG TRỊ GIÁ  10400.000000   10400.000000
# 4843        4843  Khu vực kinh tế trong nước   4600.000000    4600.000000
# 4844        4844    Khu vực có vốn đầu tư NN   5800.000000    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     13.559546  16.849002  2024-10-29  2024-10  2024-09   5.800523
# 1     18.609915  18.809906  2024-10-29  2024-10  2024-09  15.897686
# 2     10.703355  15.756936  2024-10-29  2024-10  2024-09   0.495403
# 41    11.062436  17.326993  2024-09-29  2024-09  2024-08  -3.935266
# 42     8.363759  18.772909  2024-09-29  2024-09  2024-08  -8.870482
# ...         ...        ...         ...      ...      ...        ...
# 4805        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4806        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4842  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4843  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4844  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [388 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35587.417147  335585.942544  10.093746
# 1  Khu vực kinh tế trong nước  10297.449587   93973.607944  17.741536
# 2    Khu vực có vốn đầu tư NN  25289.967560  241612.334600   7.257046
# 3                TỔNG TRỊ GIÁ  34049.626711  299625.132181  10.699933
# 4  Khu vực kinh tế trong nước   9388.747833   83466.453921  15.964694
#
#    YTD-YOY-XK        Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0   14.907858  2024-10-29  2024-10  2024-09   4.516321  33600.609501
# 1   20.661341  2024-10-29  2024-10  2024-09   9.678626  12677.810227
# 2   12.815584  2024-10-29  2024-10  2024-09   2.550958  20922.799274
# 3   15.363247  2024-09-29  2024-09  2024-08  -9.417597  31758.453093
# 4   20.727379  2024-09-29  2024-09  2024-08 -13.365525  10938.795000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  312280.088703  13.559546   16.849002   5.800523     1986.807646
# 1  113579.094880  18.609915   18.809906  15.897686    -2380.360640
# 2  198700.993823  10.703355   15.756936   0.495403     4367.168286
# 3  278842.181313  11.062436   17.326993  -3.935266     2291.173618
# 4  100848.495188   8.363759   18.772909  -8.870482    -1550.047167
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         23305.853841         69188.026648             647866.031247
# 1        -19605.486936         22975.259814             207552.702824
# 2         42911.340777         46212.766834             440313.328423
# 3         20782.950868         65808.079804             578467.313494
# 4        -17382.041267         20327.542833             184314.949109

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35587.417147  335585.942544  10.093746
# 1  Khu vực kinh tế trong nước  10297.449587   93973.607944  17.741536
# 2    Khu vực có vốn đầu tư NN  25289.967560  241612.334600   7.257046
# 3                TỔNG TRỊ GIÁ  34049.626711  299625.132181  10.699933
# 4  Khu vực kinh tế trong nước   9388.747833   83466.453921  15.964694
#
#    YTD-YOY-XK       Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0   14.907858 2024-10-29  2024-10  2024-09   4.516321  33600.609501
# 1   20.661341 2024-10-29  2024-10  2024-09   9.678626  12677.810227
# 2   12.815584 2024-10-29  2024-10  2024-09   2.550958  20922.799274
# 3   15.363247 2024-09-29  2024-09  2024-08  -9.417597  31758.453093
# 4   20.727379 2024-09-29  2024-09  2024-08 -13.365525  10938.795000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  312280.088703  13.559546   16.849002   5.800523     1986.807646
# 1  113579.094880  18.609915   18.809906  15.897686    -2380.360640
# 2  198700.993823  10.703355   15.756936   0.495403     4367.168286
# 3  278842.181313  11.062436   17.326993  -3.935266     2291.173618
# 4  100848.495188   8.363759   18.772909  -8.870482    -1550.047167
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         23305.853841         69188.026648             647866.031247
# 1        -19605.486936         22975.259814             207552.702824
# 2         42911.340777         46212.766834             440313.328423
# 3         20782.950868         65808.079804             578467.313494
# 4        -17382.041267         20327.542833             184314.949109
#
#   PreYearMonth
# 0      2023-10
# 1      2023-10
# 2      2023-10
# 3      2023-09
# 4      2023-09

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
