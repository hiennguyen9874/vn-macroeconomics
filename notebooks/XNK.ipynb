# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M     Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  31109.320468  64268.238065
# 1              1  Khu vực kinh tế trong nước   8388.000000  17923.296173
# 2              2    Khu vực có vốn đầu tư NN  22720.642807  46344.941892
# 45            45                TỔNG TRỊ GIÁ  33085.291801  33085.291801
# 46            46  Khu vực kinh tế trong nước   9489.880303   9489.880303
# ...          ...                         ...           ...           ...
# 4992        4992  Khu vực kinh tế trong nước   3270.000000   7205.000000
# 4993        4993    Khu vực có vốn đầu tư NN   6330.000000  13855.000000
# 5026        5026                TỔNG TRỊ GIÁ  10300.000000  10300.000000
# 5027        5027  Khu vực kinh tế trong nước   3520.000000   3520.000000
# 5028        5028    Khu vực có vốn đầu tư NN   6780.000000   6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     25.667320   8.352736  2025-02-28  2025-02  2025-01  -5.972356
# 1     32.841524  12.773844  2025-02-28  2025-02  2025-01 -11.611109
# 2     23.210571   6.734495  2025-02-28  2025-02  2025-01  -3.707368
# 45    -4.263233  -4.263233  2025-01-29  2025-01  2024-12  -6.878038
# 46    -0.923450  -0.923450  2025-01-29  2025-01  2024-12 -11.167074
# ...         ...        ...         ...      ...      ...        ...
# 4992        NaN  13.200000  2014-02-28  2014-02  2014-01  -7.102273
# 4993        NaN  11.800000  2014-02-28  2014-02  2014-01  -6.637168
# 5026 -10.800000 -10.800000  2014-01-29  2014-01  2013-12        NaN
# 5027 -13.800000 -13.800000  2014-01-29  2014-01  2013-12        NaN
# 5028  -9.200000  -9.200000  2014-01-29  2014-01  2013-12        NaN
#
# [400 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M     Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  32659.284980  62798.856330
# 1              1  Khu vực kinh tế trong nước  11874.165548  22794.331782
# 2              2    Khu vực có vốn đầu tư NN  20785.119432  40004.524548
# 50            50                TỔNG TRỊ GIÁ  30060.507368  30060.507368
# 51            51  Khu vực kinh tế trong nước  10891.665403  10891.665403
# ...          ...                         ...           ...           ...
# 4998        4998  Khu vực kinh tế trong nước   4650.000000   9059.000000
# 4999        4999    Khu vực có vốn đầu tư NN   6150.000000  11757.000000
# 5035        5035                TỔNG TRỊ GIÁ  10400.000000  10400.000000
# 5036        5036  Khu vực kinh tế trong nước   4600.000000   4600.000000
# 5037        5037    Khu vực có vốn đầu tư NN   5800.000000   5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     39.990739  15.898275  2025-02-28  2025-02  2025-01   8.645156
# 1     49.558183  18.706060  2025-02-28  2025-02  2025-01   9.020660
# 2     35.055057  14.357030  2025-02-28  2025-02  2025-01   8.431795
# 50    -2.574474  -2.574474  2025-01-29  2025-01  2024-12 -14.125121
# 51    -3.295538  -3.295538  2025-01-29  2025-01  2024-12 -22.198743
# ...         ...        ...         ...      ...      ...        ...
# 4998        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4999        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 5035  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 5036  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 5037  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [400 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK  Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  31109.320468  64268.238065  25.667320
# 1  Khu vực kinh tế trong nước   8388.000000  17923.296173  32.841524
# 2    Khu vực có vốn đầu tư NN  22720.642807  46344.941892  23.210571
# 3                TỔNG TRỊ GIÁ  33085.291801  33085.291801  -4.263233
# 4  Khu vực kinh tế trong nước   9489.880303   9489.880303  -0.923450
#
#    YTD-YOY-XK        Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0    8.352736  2025-02-28  2025-02  2025-01  -5.972356  32659.284980
# 1   12.773844  2025-02-28  2025-02  2025-01 -11.611109  11874.165548
# 2    6.734495  2025-02-28  2025-02  2025-01  -3.707368  20785.119432
# 3   -4.263233  2025-01-29  2025-01  2024-12  -6.878038  30060.507368
# 4   -0.923450  2025-01-29  2025-01  2024-12 -11.167074  10891.665403
#
#    Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  62798.856330  39.990739   15.898275   8.645156    -1549.964512
# 1  22794.331782  49.558183   18.706060   9.020660    -3486.165548
# 2  40004.524548  35.055057   14.357030   8.431795     1935.523375
# 3  30060.507368  -2.574474   -2.574474 -14.125121     3024.784433
# 4  10891.665403  -3.295538   -3.295538 -22.198743    -1401.785100
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0          1469.381735         63768.605448             127067.094395
# 1         -4871.035609         20262.165548              40717.627955
# 2          6340.417344         43505.762239              86349.466440
# 3          3024.784433         63145.799169              63145.799169
# 4         -1401.785100         20381.545706              20381.545706

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK  Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  31109.320468  64268.238065  25.667320
# 1  Khu vực kinh tế trong nước   8388.000000  17923.296173  32.841524
# 2    Khu vực có vốn đầu tư NN  22720.642807  46344.941892  23.210571
# 3                TỔNG TRỊ GIÁ  33085.291801  33085.291801  -4.263233
# 4  Khu vực kinh tế trong nước   9489.880303   9489.880303  -0.923450
#
#    YTD-YOY-XK       Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0    8.352736 2025-02-28  2025-02  2025-01  -5.972356  32659.284980
# 1   12.773844 2025-02-28  2025-02  2025-01 -11.611109  11874.165548
# 2    6.734495 2025-02-28  2025-02  2025-01  -3.707368  20785.119432
# 3   -4.263233 2025-01-29  2025-01  2024-12  -6.878038  30060.507368
# 4   -0.923450 2025-01-29  2025-01  2024-12 -11.167074  10891.665403
#
#    Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  62798.856330  39.990739   15.898275   8.645156    -1549.964512
# 1  22794.331782  49.558183   18.706060   9.020660    -3486.165548
# 2  40004.524548  35.055057   14.357030   8.431795     1935.523375
# 3  30060.507368  -2.574474   -2.574474 -14.125121     3024.784433
# 4  10891.665403  -3.295538   -3.295538 -22.198743    -1401.785100
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0          1469.381735         63768.605448             127067.094395
# 1         -4871.035609         20262.165548              40717.627955
# 2          6340.417344         43505.762239              86349.466440
# 3          3024.784433         63145.799169              63145.799169
# 4         -1401.785100         20381.545706              20381.545706
#
#   PreYearMonth
# 0      2024-02
# 1      2024-02
# 2      2024-02
# 3      2024-01
# 4      2024-01

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
