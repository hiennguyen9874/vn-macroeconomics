# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  35920.000000  226980.000000
# 1              1  Khu vực kinh tế trong nước   9869.392088   63083.744807
# 2              2    Khu vực có vốn đầu tư NN  26050.607912  163896.255193
# 41            41                TỔNG TRỊ GIÁ  33090.000000  190080.000000
# 42            42  Khu vực kinh tế trong nước   9334.743590   53391.262374
# ...          ...                         ...           ...            ...
# 4691        4691  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4692        4692    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4725        4725                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4726        4726  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4727        4727    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth       MOM
# 0     19.109453  15.719210  2024-07-29  2024-07  2024-06  8.552433
# 1     25.909981  21.068710  2024-07-29  2024-07  2024-06  5.727511
# 2     16.721068  13.784076  2024-07-29  2024-07  2024-06  9.662499
# 41    10.518566  14.512872  2024-06-29  2024-06  2024-05  0.853398
# 42    16.592878  20.611101  2024-06-29  2024-06  2024-05 -0.399173
# ...         ...        ...         ...      ...      ...       ...
# 4691        NaN  13.200000  2014-02-28  2014-02  2014-01 -7.102273
# 4692        NaN  11.800000  2014-02-28  2014-02  2014-01 -6.637168
# 4725 -10.800000 -10.800000  2014-01-29  2014-01  2013-12       NaN
# 4726 -13.800000 -13.800000  2014-01-29  2014-01  2013-12       NaN
# 4727  -9.200000  -9.200000  2014-01-29  2014-01  2013-12       NaN
#
# [379 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành  Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  33800.0  212900.000000
# 1              1  Khu vực kinh tế trong nước  12200.0   78001.256828
# 2              2    Khu vực có vốn đầu tư NN  21600.0  134898.743172
# 41            41                TỔNG TRỊ GIÁ  30150.0  178450.000000
# 42            42  Khu vực kinh tế trong nước  10950.0   65739.743604
# ...          ...                         ...      ...            ...
# 4682        4682  Khu vực kinh tế trong nước   4650.0    9059.000000
# 4683        4683    Khu vực có vốn đầu tư NN   6150.0   11757.000000
# 4719        4719                TỔNG TRỊ GIÁ  10400.0   10400.000000
# 4720        4720  Khu vực kinh tế trong nước   4600.0    4600.000000
# 4721        4721    Khu vực có vốn đầu tư NN   5800.0    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     24.730544  18.508884  2024-07-29  2024-07  2024-06  12.106136
# 1     16.527509  21.473829  2024-07-29  2024-07  2024-06  11.415525
# 2     29.895248  16.859613  2024-07-29  2024-07  2024-06  12.500000
# 41    13.124445  16.977608  2024-06-29  2024-06  2024-05 -10.825200
# 42    15.488678  22.322964  2024-06-29  2024-06  2024-05 -14.519906
# ...         ...        ...         ...      ...      ...        ...
# 4682        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4683        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4719  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4720  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4721  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [379 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35920.000000  226980.000000  19.109453
# 1  Khu vực kinh tế trong nước   9869.392088   63083.744807  25.909981
# 2    Khu vực có vốn đầu tư NN  26050.607912  163896.255193  16.721068
# 3                TỔNG TRỊ GIÁ  33090.000000  190080.000000  10.518566
# 4  Khu vực kinh tế trong nước   9334.743590   53391.262374  16.592878
#
#    YTD-YOY-XK        Date    Month PreMonth    MOM-XK  Total-M-NK  \
# 0   15.719210  2024-07-29  2024-07  2024-06  8.552433     33800.0
# 1   21.068710  2024-07-29  2024-07  2024-06  5.727511     12200.0
# 2   13.784076  2024-07-29  2024-07  2024-06  9.662499     21600.0
# 3   14.512872  2024-06-29  2024-06  2024-05  0.853398     30150.0
# 4   20.611101  2024-06-29  2024-06  2024-05 -0.399173     10950.0
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  212900.000000  24.730544   18.508884  12.106136     2120.000000
# 1   78001.256828  16.527509   21.473829  11.415525    -2330.607912
# 2  134898.743172  29.895248   16.859613  12.500000     4450.607912
# 3  178450.000000  13.124445   16.977608 -10.825200     2940.000000
# 4   65739.743604  15.488678   22.322964 -14.519906    -1615.256410
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         14080.000000         69720.000000             439880.000000
# 1        -14917.512021         22069.392088             141085.001635
# 2         28997.512021         47650.607912             298794.998365
# 3         11630.000000         63240.000000             368530.000000
# 4        -12348.481230         20284.743590             119131.005978

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35920.000000  226980.000000  19.109453
# 1  Khu vực kinh tế trong nước   9869.392088   63083.744807  25.909981
# 2    Khu vực có vốn đầu tư NN  26050.607912  163896.255193  16.721068
# 3                TỔNG TRỊ GIÁ  33090.000000  190080.000000  10.518566
# 4  Khu vực kinh tế trong nước   9334.743590   53391.262374  16.592878
#
#    YTD-YOY-XK       Date    Month PreMonth    MOM-XK  Total-M-NK  \
# 0   15.719210 2024-07-29  2024-07  2024-06  8.552433     33800.0
# 1   21.068710 2024-07-29  2024-07  2024-06  5.727511     12200.0
# 2   13.784076 2024-07-29  2024-07  2024-06  9.662499     21600.0
# 3   14.512872 2024-06-29  2024-06  2024-05  0.853398     30150.0
# 4   20.611101 2024-06-29  2024-06  2024-05 -0.399173     10950.0
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  212900.000000  24.730544   18.508884  12.106136     2120.000000
# 1   78001.256828  16.527509   21.473829  11.415525    -2330.607912
# 2  134898.743172  29.895248   16.859613  12.500000     4450.607912
# 3  178450.000000  13.124445   16.977608 -10.825200     2940.000000
# 4   65739.743604  15.488678   22.322964 -14.519906    -1615.256410
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         14080.000000         69720.000000             439880.000000
# 1        -14917.512021         22069.392088             141085.001635
# 2         28997.512021         47650.607912             298794.998365
# 3         11630.000000         63240.000000             368530.000000
# 4        -12348.481230         20284.743590             119131.005978
#
#   PreYearMonth
# 0      2023-07
# 1      2023-07
# 2      2023-07
# 3      2023-06
# 4      2023-06

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
