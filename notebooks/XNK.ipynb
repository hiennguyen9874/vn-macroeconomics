# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  37589.670481  265091.000000
# 1              1  Khu vực kinh tế trong nước  10837.195981   73876.607760
# 2              2    Khu vực có vốn đầu tư NN  26753.000000  191214.392240
# 41            41                TỔNG TRỊ GIÁ  35920.000000  226980.000000
# 42            42  Khu vực kinh tế trong nước   9869.392088   63083.744807
# ...          ...                         ...           ...            ...
# 4732        4732  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4733        4733    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4766        4766                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4767        4767  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4768        4768    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth       MOM
# 0     14.541485  15.778097  2024-08-29  2024-08  2024-07  4.648303
# 1     21.297973  21.029637  2024-08-29  2024-08  2024-07  9.806115
# 2     12.013977  13.869178  2024-08-29  2024-08  2024-07  2.696260
# 41    19.109453  15.719210  2024-07-29  2024-07  2024-06  8.552433
# 42    25.909981  21.068710  2024-07-29  2024-07  2024-06  5.727511
# ...         ...        ...         ...      ...      ...       ...
# 4732        NaN  13.200000  2014-02-28  2014-02  2014-01 -7.102273
# 4733        NaN  11.800000  2014-02-28  2014-02  2014-01 -6.637168
# 4766 -10.800000 -10.800000  2014-01-29  2014-01  2013-12       NaN
# 4767 -13.800000 -13.800000  2014-01-29  2014-01  2013-12       NaN
# 4768  -9.200000  -9.200000  2014-01-29  2014-01  2013-12       NaN
#
# [382 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  33059.429595  246018.000000
# 1              1  Khu vực kinh tế trong nước  12003.569481   89577.772549
# 2              2    Khu vực có vốn đầu tư NN  21055.860114  156440.227451
# 41            41                TỔNG TRỊ GIÁ  33800.000000  212900.000000
# 42            42  Khu vực kinh tế trong nước  12200.000000   78001.256828
# ...          ...                         ...           ...            ...
# 4723        4723  Khu vực kinh tế trong nước   4650.000000    9059.000000
# 4724        4724    Khu vực có vốn đầu tư NN   6150.000000   11757.000000
# 4760        4760                TỔNG TRỊ GIÁ  10400.000000   10400.000000
# 4761        4761  Khu vực kinh tế trong nước   4600.000000    4600.000000
# 4762        4762    Khu vực có vốn đầu tư NN   5800.000000    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     12.377029  17.674073  2024-08-29  2024-08  2024-07  -2.191037
# 1     13.222450  19.733724  2024-08-29  2024-08  2024-07  -1.610086
# 2     11.900696  16.526307  2024-08-29  2024-08  2024-07  -2.519166
# 41    24.730544  18.508884  2024-07-29  2024-07  2024-06  12.106136
# 42    16.527509  21.473829  2024-07-29  2024-07  2024-06  11.415525
# ...         ...        ...         ...      ...      ...        ...
# 4723        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4724        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4760  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4761  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4762  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [382 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  37589.670481  265091.000000  14.541485
# 1  Khu vực kinh tế trong nước  10837.195981   73876.607760  21.297973
# 2    Khu vực có vốn đầu tư NN  26753.000000  191214.392240  12.013977
# 3                TỔNG TRỊ GIÁ  35920.000000  226980.000000  19.109453
# 4  Khu vực kinh tế trong nước   9869.392088   63083.744807  25.909981
#
#    YTD-YOY-XK        Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   15.778097  2024-08-29  2024-08  2024-07  4.648303  33059.429595
# 1   21.029637  2024-08-29  2024-08  2024-07  9.806115  12003.569481
# 2   13.869178  2024-08-29  2024-08  2024-07  2.696260  21055.860114
# 3   15.719210  2024-07-29  2024-07  2024-06  8.552433  33800.000000
# 4   21.068710  2024-07-29  2024-07  2024-06  5.727511  12200.000000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  246018.000000  12.377029   17.674073  -2.191037     4530.240886
# 1   89577.772549  13.222450   19.733724  -1.610086    -1166.373500
# 2  156440.227451  11.900696   16.526307  -2.519166     5697.139886
# 3  212900.000000  24.730544   18.508884  12.106136     2120.000000
# 4   78001.256828  16.527509   21.473829  11.415525    -2330.607912
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         19073.000000         70649.100076             511109.000000
# 1        -15701.164789         22840.765462             163454.380309
# 2         34774.164789         47808.860114             347654.619691
# 3         14080.000000         69720.000000             439880.000000
# 4        -14917.512021         22069.392088             141085.001635

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  37589.670481  265091.000000  14.541485
# 1  Khu vực kinh tế trong nước  10837.195981   73876.607760  21.297973
# 2    Khu vực có vốn đầu tư NN  26753.000000  191214.392240  12.013977
# 3                TỔNG TRỊ GIÁ  35920.000000  226980.000000  19.109453
# 4  Khu vực kinh tế trong nước   9869.392088   63083.744807  25.909981
#
#    YTD-YOY-XK       Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   15.778097 2024-08-29  2024-08  2024-07  4.648303  33059.429595
# 1   21.029637 2024-08-29  2024-08  2024-07  9.806115  12003.569481
# 2   13.869178 2024-08-29  2024-08  2024-07  2.696260  21055.860114
# 3   15.719210 2024-07-29  2024-07  2024-06  8.552433  33800.000000
# 4   21.068710 2024-07-29  2024-07  2024-06  5.727511  12200.000000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  246018.000000  12.377029   17.674073  -2.191037     4530.240886
# 1   89577.772549  13.222450   19.733724  -1.610086    -1166.373500
# 2  156440.227451  11.900696   16.526307  -2.519166     5697.139886
# 3  212900.000000  24.730544   18.508884  12.106136     2120.000000
# 4   78001.256828  16.527509   21.473829  11.415525    -2330.607912
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         19073.000000         70649.100076             511109.000000
# 1        -15701.164789         22840.765462             163454.380309
# 2         34774.164789         47808.860114             347654.619691
# 3         14080.000000         69720.000000             439880.000000
# 4        -14917.512021         22069.392088             141085.001635
#
#   PreYearMonth
# 0      2023-08
# 1      2023-08
# 2      2023-08
# 3      2023-07
# 4      2023-07

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
