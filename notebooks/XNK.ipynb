# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  33090.000000  190080.000000
# 1              1  Khu vực kinh tế trong nước   9334.743590   53391.262374
# 2              2    Khu vực có vốn đầu tư NN  23755.256410  136688.737626
# 41            41                TỔNG TRỊ GIÁ  32810.000000  156770.000000
# 42            42  Khu vực kinh tế trong nước   9372.154678   43687.553326
# ...          ...                         ...           ...            ...
# 4650        4650  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4651        4651    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4684        4684                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4685        4685  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4686        4686    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth       MOM
# 0     10.518566  14.512872  2024-06-29  2024-06  2024-05  0.853398
# 1     16.592878  20.611101  2024-06-29  2024-06  2024-05 -0.399173
# 2      8.301382  12.295112  2024-06-29  2024-06  2024-05  1.354267
# 41    15.835895  15.230202  2024-05-29  2024-05  2024-04  6.043956
# 42    13.025826  20.480780  2024-05-29  2024-05  2024-04  7.392715
# ...         ...        ...         ...      ...      ...       ...
# 4650        NaN  13.200000  2014-02-28  2014-02  2014-01 -7.102273
# 4651        NaN  11.800000  2014-02-28  2014-02  2014-01 -6.637168
# 4684 -10.800000 -10.800000  2014-01-29  2014-01  2013-12       NaN
# 4685 -13.800000 -13.800000  2014-01-29  2014-01  2013-12       NaN
# 4686  -9.200000  -9.200000  2014-01-29  2014-01  2013-12       NaN
#
# [376 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành  Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  30150.0  178450.000000
# 1              1  Khu vực kinh tế trong nước  10950.0   65739.743604
# 2              2    Khu vực có vốn đầu tư NN  19200.0  112710.256396
# 41            41                TỔNG TRỊ GIÁ  33810.0  148760.000000
# 42            42  Khu vực kinh tế trong nước  12810.0   54950.969179
# ...          ...                         ...      ...            ...
# 4641        4641  Khu vực kinh tế trong nước   4650.0    9059.000000
# 4642        4642    Khu vực có vốn đầu tư NN   6150.0   11757.000000
# 4678        4678                TỔNG TRỊ GIÁ  10400.0   10400.000000
# 4679        4679  Khu vực kinh tế trong nước   4600.0    4600.000000
# 4680        4680    Khu vực có vốn đầu tư NN   5800.0    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     13.124445  16.977608  2024-06-29  2024-06  2024-05 -10.825200
# 1     15.488678  22.322964  2024-06-29  2024-06  2024-05 -14.519906
# 2     11.818939  14.070203  2024-06-29  2024-06  2024-05  -8.571429
# 41    29.903705  18.158676  2024-05-29  2024-05  2024-04  11.731659
# 42    38.155978  24.151231  2024-05-29  2024-05  2024-04  14.272971
# ...         ...        ...         ...      ...      ...        ...
# 4641        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4642        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4678  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4679  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4680  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [376 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33090.000000  190080.000000  10.518566
# 1  Khu vực kinh tế trong nước   9334.743590   53391.262374  16.592878
# 2    Khu vực có vốn đầu tư NN  23755.256410  136688.737626   8.301382
# 3                TỔNG TRỊ GIÁ  32810.000000  156770.000000  15.835895
# 4  Khu vực kinh tế trong nước   9372.154678   43687.553326  13.025826
#
#    YTD-YOY-XK        Date    Month PreMonth    MOM-XK  Total-M-NK  \
# 0   14.512872  2024-06-29  2024-06  2024-05  0.853398     30150.0
# 1   20.611101  2024-06-29  2024-06  2024-05 -0.399173     10950.0
# 2   12.295112  2024-06-29  2024-06  2024-05  1.354267     19200.0
# 3   15.230202  2024-05-29  2024-05  2024-04  6.043956     33810.0
# 4   20.480780  2024-05-29  2024-05  2024-04  7.392715     12810.0
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  178450.000000  13.124445   16.977608 -10.825200     2940.000000
# 1   65739.743604  15.488678   22.322964 -14.519906    -1615.256410
# 2  112710.256396  11.818939   14.070203  -8.571429     4555.256410
# 3  148760.000000  29.903705   18.158676  11.731659    -1000.000000
# 4   54950.969179  38.155978   24.151231  14.272971    -3437.845322
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         11630.000000         63240.000000             368530.000000
# 1        -12348.481230         20284.743590             119131.005978
# 2         23978.481230         42955.256410             249398.994022
# 3          8010.000000         66620.000000             305530.000000
# 4        -11263.415853         22182.154678              98638.522505

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33090.000000  190080.000000  10.518566
# 1  Khu vực kinh tế trong nước   9334.743590   53391.262374  16.592878
# 2    Khu vực có vốn đầu tư NN  23755.256410  136688.737626   8.301382
# 3                TỔNG TRỊ GIÁ  32810.000000  156770.000000  15.835895
# 4  Khu vực kinh tế trong nước   9372.154678   43687.553326  13.025826
#
#    YTD-YOY-XK       Date    Month PreMonth    MOM-XK  Total-M-NK  \
# 0   14.512872 2024-06-29  2024-06  2024-05  0.853398     30150.0
# 1   20.611101 2024-06-29  2024-06  2024-05 -0.399173     10950.0
# 2   12.295112 2024-06-29  2024-06  2024-05  1.354267     19200.0
# 3   15.230202 2024-05-29  2024-05  2024-04  6.043956     33810.0
# 4   20.480780 2024-05-29  2024-05  2024-04  7.392715     12810.0
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  178450.000000  13.124445   16.977608 -10.825200     2940.000000
# 1   65739.743604  15.488678   22.322964 -14.519906    -1615.256410
# 2  112710.256396  11.818939   14.070203  -8.571429     4555.256410
# 3  148760.000000  29.903705   18.158676  11.731659    -1000.000000
# 4   54950.969179  38.155978   24.151231  14.272971    -3437.845322
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         11630.000000         63240.000000             368530.000000
# 1        -12348.481230         20284.743590             119131.005978
# 2         23978.481230         42955.256410             249398.994022
# 3          8010.000000         66620.000000             305530.000000
# 4        -11263.415853         22182.154678              98638.522505
#
#   PreYearMonth
# 0      2023-06
# 1      2023-06
# 2      2023-06
# 3      2023-05
# 4      2023-05

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
