# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  33733.773009  369934.689621
# 1              1  Khu vực kinh tế trong nước   9850.121179  103883.177724
# 2              2    Khu vực có vốn đầu tư NN  23883.651830  266051.511897
# 43            43                TỔNG TRỊ GIÁ  35587.417147  335585.942544
# 44            44  Khu vực kinh tế trong nước  10297.449587   93973.607944
# ...          ...                         ...           ...            ...
# 4857        4857  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4858        4858    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4891        4891                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4892        4892  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4893        4893    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth       MOM
# 0      8.159821  14.447001  2024-11-29  2024-11  2024-10 -5.208707
# 1     13.399940  20.001412  2024-11-29  2024-11  2024-10 -4.344070
# 2      6.137099  12.415315  2024-11-29  2024-11  2024-10 -5.560765
# 43    10.093746  14.907858  2024-10-29  2024-10  2024-09  4.516321
# 44    17.741536  20.661341  2024-10-29  2024-10  2024-09  9.678626
# ...         ...        ...         ...      ...      ...       ...
# 4857        NaN  13.200000  2014-02-28  2014-02  2014-01 -7.102273
# 4858        NaN  11.800000  2014-02-28  2014-02  2014-01 -6.637168
# 4891 -10.800000 -10.800000  2014-01-29  2014-01  2013-12       NaN
# 4892 -13.800000 -13.800000  2014-01-29  2014-01  2013-12       NaN
# 4893  -9.200000  -9.200000  2014-01-29  2014-01  2013-12       NaN
#
# [391 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  32667.000000  345622.247848
# 1              1  Khu vực kinh tế trong nước  12375.000000  126055.986808
# 2              2    Khu vực có vốn đầu tư NN  20292.000000  219566.261040
# 43            43                TỔNG TRỊ GIÁ  33600.609501  312280.088703
# 44            44  Khu vực kinh tế trong nước  12677.810227  113579.094880
# ...          ...                         ...           ...            ...
# 4848        4848  Khu vực kinh tế trong nước   4650.000000    9059.000000
# 4849        4849    Khu vực có vốn đầu tư NN   6150.000000   11757.000000
# 4885        4885                TỔNG TRỊ GIÁ  10400.000000   10400.000000
# 4886        4886  Khu vực kinh tế trong nước   4600.000000    4600.000000
# 4887        4887    Khu vực có vốn đầu tư NN   5800.000000    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0      9.811321  16.371327  2024-11-29  2024-11  2024-10  -2.778549
# 1     15.202351  18.540790  2024-11-29  2024-11  2024-10  -2.388506
# 2      6.764259  15.161317  2024-11-29  2024-11  2024-10  -3.014889
# 43    13.559546  16.849002  2024-10-29  2024-10  2024-09   5.800523
# 44    18.609915  18.809906  2024-10-29  2024-10  2024-09  15.897686
# ...         ...        ...         ...      ...      ...        ...
# 4848        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4849        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4885  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4886  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4887  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [391 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33733.773009  369934.689621   8.159821
# 1  Khu vực kinh tế trong nước   9850.121179  103883.177724  13.399940
# 2    Khu vực có vốn đầu tư NN  23883.651830  266051.511897   6.137099
# 3                TỔNG TRỊ GIÁ  35587.417147  335585.942544  10.093746
# 4  Khu vực kinh tế trong nước  10297.449587   93973.607944  17.741536
#
#    YTD-YOY-XK        Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   14.447001  2024-11-29  2024-11  2024-10 -5.208707  32667.000000
# 1   20.001412  2024-11-29  2024-11  2024-10 -4.344070  12375.000000
# 2   12.415315  2024-11-29  2024-11  2024-10 -5.560765  20292.000000
# 3   14.907858  2024-10-29  2024-10  2024-09  4.516321  33600.609501
# 4   20.661341  2024-10-29  2024-10  2024-09  9.678626  12677.810227
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  345622.247848   9.811321   16.371327  -2.778549     1066.773009
# 1  126055.986808  15.202351   18.540790  -2.388506    -2524.878821
# 2  219566.261040   6.764259   15.161317  -3.014889     3591.651830
# 3  312280.088703  13.559546   16.849002   5.800523     1986.807646
# 4  113579.094880  18.609915   18.809906  15.897686    -2380.360640
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         24312.441773         66400.773009             715556.937469
# 1        -22172.809084         22225.121179             229939.164532
# 2         46485.250857         44175.651830             485617.772937
# 3         23305.853841         69188.026648             647866.031247
# 4        -19605.486936         22975.259814             207552.702824

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33733.773009  369934.689621   8.159821
# 1  Khu vực kinh tế trong nước   9850.121179  103883.177724  13.399940
# 2    Khu vực có vốn đầu tư NN  23883.651830  266051.511897   6.137099
# 3                TỔNG TRỊ GIÁ  35587.417147  335585.942544  10.093746
# 4  Khu vực kinh tế trong nước  10297.449587   93973.607944  17.741536
#
#    YTD-YOY-XK       Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   14.447001 2024-11-29  2024-11  2024-10 -5.208707  32667.000000
# 1   20.001412 2024-11-29  2024-11  2024-10 -4.344070  12375.000000
# 2   12.415315 2024-11-29  2024-11  2024-10 -5.560765  20292.000000
# 3   14.907858 2024-10-29  2024-10  2024-09  4.516321  33600.609501
# 4   20.661341 2024-10-29  2024-10  2024-09  9.678626  12677.810227
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  345622.247848   9.811321   16.371327  -2.778549     1066.773009
# 1  126055.986808  15.202351   18.540790  -2.388506    -2524.878821
# 2  219566.261040   6.764259   15.161317  -3.014889     3591.651830
# 3  312280.088703  13.559546   16.849002   5.800523     1986.807646
# 4  113579.094880  18.609915   18.809906  15.897686    -2380.360640
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         24312.441773         66400.773009             715556.937469
# 1        -22172.809084         22225.121179             229939.164532
# 2         46485.250857         44175.651830             485617.772937
# 3         23305.853841         69188.026648             647866.031247
# 4        -19605.486936         22975.259814             207552.702824
#
#   PreYearMonth
# 0      2023-11
# 1      2023-11
# 2      2023-11
# 3      2023-10
# 4      2023-10

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
