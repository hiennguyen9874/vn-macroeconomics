# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M        YOY  \
# 0              0                TỔNG TRỊ GIÁ  33085.291801  -4.263233
# 1              1  Khu vực kinh tế trong nước   9489.880303  -0.923450
# 2              2    Khu vực có vốn đầu tư NN  23595.411498  -5.543825
# 45            45                TỔNG TRỊ GIÁ  35528.989183  12.846648
# 46            46  Khu vực kinh tế trong nước  10682.841116  17.554105
# ...          ...                         ...           ...        ...
# 4947        4947  Khu vực kinh tế trong nước   3270.000000        NaN
# 4948        4948    Khu vực có vốn đầu tư NN   6330.000000        NaN
# 4981        4981                TỔNG TRỊ GIÁ  10300.000000 -10.800000
# 4982        4982  Khu vực kinh tế trong nước   3520.000000 -13.800000
# 4983        4983    Khu vực có vốn đầu tư NN   6780.000000  -9.200000
#
#           Total-YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0      33085.291801  -4.263233  2025-01-29  2025-01  2024-12  -6.878038
# 1       9489.880303  -0.923450  2025-01-29  2025-01  2024-12 -11.167074
# 2      23595.411498  -5.543825  2025-01-29  2025-01  2024-12  -5.033925
# 45    405531.740609  14.324144  2024-12-29  2024-12  2024-11   5.321718
# 46    114593.084780  19.797205  2024-12-29  2024-12  2024-11   8.453906
# ...             ...        ...         ...      ...      ...        ...
# 4947    7205.000000  13.200000  2014-02-28  2014-02  2014-01  -7.102273
# 4948   13855.000000  11.800000  2014-02-28  2014-02  2014-01  -6.637168
# 4981   10300.000000 -10.800000  2014-01-29  2014-01  2013-12        NaN
# 4982    3520.000000 -13.800000  2014-01-29  2014-01  2013-12        NaN
# 4983    6780.000000  -9.200000  2014-01-29  2014-01  2013-12        NaN
#
# [397 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M        YOY  \
# 0              0                TỔNG TRỊ GIÁ  30060.507368  -2.574474
# 1              1  Khu vực kinh tế trong nước  10891.665403  -3.295538
# 2              2    Khu vực có vốn đầu tư NN  19168.841965  -2.159958
# 50            50                TỔNG TRỊ GIÁ  35005.006915  19.233183
# 51            51  Khu vực kinh tế trong nước  13999.343757  27.746998
# ...          ...                         ...           ...        ...
# 4948        4948  Khu vực kinh tế trong nước   4650.000000        NaN
# 4949        4949    Khu vực có vốn đầu tư NN   6150.000000        NaN
# 4985        4985                TỔNG TRỊ GIÁ  10400.000000  -1.900000
# 4986        4986  Khu vực kinh tế trong nước   4600.000000  -2.300000
# 4987        4987    Khu vực có vốn đầu tư NN   5800.000000  -1.500000
#
#           Total-YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0      30060.507368  -2.574474  2025-01-29  2025-01  2024-12 -14.125121
# 1      10891.665403  -3.295538  2025-01-29  2025-01  2024-12 -22.198743
# 2      19168.841965  -2.159958  2025-01-29  2025-01  2024-12  -8.744409
# 50    380763.672762  16.670573  2024-12-29  2024-12  2024-11   7.157091
# 51    140113.589138  19.450551  2024-12-29  2024-12  2024-11  13.126010
# ...             ...        ...         ...      ...      ...        ...
# 4948    9059.000000  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4949   11757.000000  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4985   10400.000000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4986    4600.000000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4987    5800.000000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [397 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK     YOY-XK   Total-YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33085.291801  -4.263233   33085.291801
# 1  Khu vực kinh tế trong nước   9489.880303  -0.923450    9489.880303
# 2    Khu vực có vốn đầu tư NN  23595.411498  -5.543825   23595.411498
# 3                TỔNG TRỊ GIÁ  35528.989183  12.846648  405531.740609
# 4  Khu vực kinh tế trong nước  10682.841116  17.554105  114593.084780
#
#    YTD-YOY-XK        Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0   -4.263233  2025-01-29  2025-01  2024-12  -6.878038  30060.507368
# 1   -0.923450  2025-01-29  2025-01  2024-12 -11.167074  10891.665403
# 2   -5.543825  2025-01-29  2025-01  2024-12  -5.033925  19168.841965
# 3   14.324144  2024-12-29  2024-12  2024-11   5.321718  35005.006915
# 4   19.797205  2024-12-29  2024-12  2024-11   8.453906  13999.343757
#
#       YOY-NK   Total-YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  -2.574474   30060.507368   -2.574474 -14.125121     3024.784433
# 1  -3.295538   10891.665403   -3.295538 -22.198743    -1401.785100
# 2  -2.159958   19168.841965   -2.159958  -8.744409     4426.569533
# 3  19.233183  380763.672762   16.670573   7.157091      523.982268
# 4  27.746998  140113.589138   19.450551  13.126010    -3316.502641
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0          3024.784433         63145.799169              63145.799169
# 1         -1401.785100         20381.545706              20381.545706
# 2          4426.569533         42764.253463              42764.253463
# 3         24768.067847         70533.996098             786295.413371
# 4        -25520.504358         24682.184873             254706.673918

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK     YOY-XK   Total-YOY-XK  \
# 0                TỔNG TRỊ GIÁ  33085.291801  -4.263233   33085.291801
# 1  Khu vực kinh tế trong nước   9489.880303  -0.923450    9489.880303
# 2    Khu vực có vốn đầu tư NN  23595.411498  -5.543825   23595.411498
# 3                TỔNG TRỊ GIÁ  35528.989183  12.846648  405531.740609
# 4  Khu vực kinh tế trong nước  10682.841116  17.554105  114593.084780
#
#    YTD-YOY-XK       Date    Month PreMonth     MOM-XK    Total-M-NK  \
# 0   -4.263233 2025-01-29  2025-01  2024-12  -6.878038  30060.507368
# 1   -0.923450 2025-01-29  2025-01  2024-12 -11.167074  10891.665403
# 2   -5.543825 2025-01-29  2025-01  2024-12  -5.033925  19168.841965
# 3   14.324144 2024-12-29  2024-12  2024-11   5.321718  35005.006915
# 4   19.797205 2024-12-29  2024-12  2024-11   8.453906  13999.343757
#
#       YOY-NK   Total-YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  -2.574474   30060.507368   -2.574474 -14.125121     3024.784433
# 1  -3.295538   10891.665403   -3.295538 -22.198743    -1401.785100
# 2  -2.159958   19168.841965   -2.159958  -8.744409     4426.569533
# 3  19.233183  380763.672762   16.670573   7.157091      523.982268
# 4  27.746998  140113.589138   19.450551  13.126010    -3316.502641
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0          3024.784433         63145.799169              63145.799169
# 1         -1401.785100         20381.545706              20381.545706
# 2          4426.569533         42764.253463              42764.253463
# 3         24768.067847         70533.996098             786295.413371
# 4        -25520.504358         24682.184873             254706.673918
#
#   PreYearMonth
# 0      2024-01
# 1      2024-01
# 2      2024-01
# 3      2023-12
# 4      2023-12

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'YOY-XK', 'Total-YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'YOY-NK', 'Total-YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'YOY-XK', 'Total-YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'YOY-NK', 'Total-YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
