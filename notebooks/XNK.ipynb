# %%
import pandas as pd

xk_df = pd.read_csv("../csv/xk.csv")
xk_df = xk_df[
    xk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
xk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  35528.989183  405531.740609
# 1              1  Khu vực kinh tế trong nước  10682.841116  114593.084780
# 2              2    Khu vực có vốn đầu tư NN  24846.148067  290938.655829
# 45            45                TỔNG TRỊ GIÁ  33733.773009  369934.689621
# 46            46  Khu vực kinh tế trong nước   9850.121179  103883.177724
# ...          ...                         ...           ...            ...
# 4902        4902  Khu vực kinh tế trong nước   3270.000000    7205.000000
# 4903        4903    Khu vực có vốn đầu tư NN   6330.000000   13855.000000
# 4936        4936                TỔNG TRỊ GIÁ  10300.000000   10300.000000
# 4937        4937  Khu vực kinh tế trong nước   3520.000000    3520.000000
# 4938        4938    Khu vực có vốn đầu tư NN   6780.000000    6780.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth       MOM
# 0     12.846648  14.324144  2024-12-29  2024-12  2024-11  5.321718
# 1     17.554105  19.797205  2024-12-29  2024-12  2024-11  8.453906
# 2     10.936571  12.303299  2024-12-29  2024-12  2024-11  4.029937
# 45     8.159821  14.447001  2024-11-29  2024-11  2024-10 -5.208707
# 46    13.399940  20.001412  2024-11-29  2024-11  2024-10 -4.344070
# ...         ...        ...         ...      ...      ...       ...
# 4902        NaN  13.200000  2014-02-28  2014-02  2014-01 -7.102273
# 4903        NaN  11.800000  2014-02-28  2014-02  2014-01 -6.637168
# 4936 -10.800000 -10.800000  2014-01-29  2014-01  2013-12       NaN
# 4937 -13.800000 -13.800000  2014-01-29  2014-01  2013-12       NaN
# 4938  -9.200000  -9.200000  2014-01-29  2014-01  2013-12       NaN
#
# [394 rows x 10 columns]

# %%
import pandas as pd

nk_df = pd.read_csv("../csv/nk.csv")
nk_df = nk_df[
    nk_df["Ngành"].isin(
        ["TỔNG TRỊ GIÁ", "Khu vực kinh tế trong nước", "Khu vực có vốn đầu tư NN"]
    )
]
nk_df
# Out:
#       Unnamed: 0                       Ngành       Total-M      Total-YOY  \
# 0              0                TỔNG TRỊ GIÁ  35005.006915  380763.672762
# 1              1  Khu vực kinh tế trong nước  13999.343757  140113.589138
# 2              2    Khu vực có vốn đầu tư NN  21005.663158  240650.083624
# 50            50                TỔNG TRỊ GIÁ  32667.000000  345622.247848
# 51            51  Khu vực kinh tế trong nước  12375.000000  126055.986808
# ...          ...                         ...           ...            ...
# 4898        4898  Khu vực kinh tế trong nước   4650.000000    9059.000000
# 4899        4899    Khu vực có vốn đầu tư NN   6150.000000   11757.000000
# 4935        4935                TỔNG TRỊ GIÁ  10400.000000   10400.000000
# 4936        4936  Khu vực kinh tế trong nước   4600.000000    4600.000000
# 4937        4937    Khu vực có vốn đầu tư NN   5800.000000    5800.000000
#
#             YOY    YTD-YOY        Date    Month PreMonth        MOM
# 0     19.233183  16.670573  2024-12-29  2024-12  2024-11   7.157091
# 1     27.746998  19.450551  2024-12-29  2024-12  2024-11  13.126010
# 2     14.162479  15.110793  2024-12-29  2024-12  2024-11   3.516968
# 50     9.811321  16.371327  2024-11-29  2024-11  2024-10  -2.778549
# 51    15.202351  18.540790  2024-11-29  2024-11  2024-10  -2.388506
# ...         ...        ...         ...      ...      ...        ...
# 4898        NaN  16.800000  2014-02-28  2014-02  2014-01   1.086957
# 4899        NaN  17.100000  2014-02-28  2014-02  2014-01   6.034483
# 4935  -1.900000  -1.900000  2014-01-29  2014-01  2013-12        NaN
# 4936  -2.300000  -2.300000  2014-01-29  2014-01  2013-12        NaN
# 4937  -1.500000  -1.500000  2014-01-29  2014-01  2013-12        NaN
#
# [393 rows x 10 columns]

# %%
xnk_merge = pd.merge(
    left=xk_df,
    right=nk_df,
    on=["Ngành", "Date", "Month", "PreMonth"],
    suffixes=("-XK", "-NK"),
)
xnk_merge = xnk_merge.drop(columns=["Unnamed: 0-XK", "Unnamed: 0-NK"])
xnk_merge["Thặng dự tháng"] = xnk_merge["Total-M-XK"] - xnk_merge["Total-M-NK"]
xnk_merge["Thặng dự từ đầu năm"] = xnk_merge["Total-YOY-XK"] - xnk_merge["Total-YOY-NK"]
xnk_merge["Kim ngạch xnk tháng"] = xnk_merge["Total-M-XK"] + xnk_merge["Total-M-NK"]
xnk_merge["Kim ngạch xnk từ đầu năm"] = (
    xnk_merge["Total-YOY-XK"] + xnk_merge["Total-YOY-NK"]
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35528.989183  405531.740609  12.846648
# 1  Khu vực kinh tế trong nước  10682.841116  114593.084780  17.554105
# 2    Khu vực có vốn đầu tư NN  24846.148067  290938.655829  10.936571
# 3                TỔNG TRỊ GIÁ  33733.773009  369934.689621   8.159821
# 4  Khu vực kinh tế trong nước   9850.121179  103883.177724  13.399940
#
#    YTD-YOY-XK        Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   14.324144  2024-12-29  2024-12  2024-11  5.321718  35005.006915
# 1   19.797205  2024-12-29  2024-12  2024-11  8.453906  13999.343757
# 2   12.303299  2024-12-29  2024-12  2024-11  4.029937  21005.663158
# 3   14.447001  2024-11-29  2024-11  2024-10 -5.208707  32667.000000
# 4   20.001412  2024-11-29  2024-11  2024-10 -4.344070  12375.000000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  380763.672762  19.233183   16.670573   7.157091      523.982268
# 1  140113.589138  27.746998   19.450551  13.126010    -3316.502641
# 2  240650.083624  14.162479   15.110793   3.516968     3840.484909
# 3  345622.247848   9.811321   16.371327  -2.778549     1066.773009
# 4  126055.986808  15.202351   18.540790  -2.388506    -2524.878821
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm
# 0         24768.067847         70533.996098             786295.413371
# 1        -25520.504358         24682.184873             254706.673918
# 2         50288.572205         45851.811225             531588.739453
# 3         24312.441773         66400.773009             715556.937469
# 4        -22172.809084         22225.121179             229939.164532

# %%
xnk_merge["Date"] = pd.to_datetime(xnk_merge["Date"], dayfirst=False)
xnk_merge["PreMonth"] = (
        xnk_merge["Date"]
        .apply(
            lambda x: (
                x.replace(month=x.month - 1, day=1)
                if x.month > 1
                else x.replace(year=x.year - 1, month=12, day=1)
            )
        )
        .dt.strftime("%Y-%m")
    )
xnk_merge["PreYearMonth"] = (
    xnk_merge["Date"]
    .apply(lambda x: x.replace(year=x.year - 1, day=1))
    .dt.strftime("%Y-%m")
)
xnk_merge.head(n=5)
# Out:
#                         Ngành    Total-M-XK   Total-YOY-XK     YOY-XK  \
# 0                TỔNG TRỊ GIÁ  35528.989183  405531.740609  12.846648
# 1  Khu vực kinh tế trong nước  10682.841116  114593.084780  17.554105
# 2    Khu vực có vốn đầu tư NN  24846.148067  290938.655829  10.936571
# 3                TỔNG TRỊ GIÁ  33733.773009  369934.689621   8.159821
# 4  Khu vực kinh tế trong nước   9850.121179  103883.177724  13.399940
#
#    YTD-YOY-XK       Date    Month PreMonth    MOM-XK    Total-M-NK  \
# 0   14.324144 2024-12-29  2024-12  2024-11  5.321718  35005.006915
# 1   19.797205 2024-12-29  2024-12  2024-11  8.453906  13999.343757
# 2   12.303299 2024-12-29  2024-12  2024-11  4.029937  21005.663158
# 3   14.447001 2024-11-29  2024-11  2024-10 -5.208707  32667.000000
# 4   20.001412 2024-11-29  2024-11  2024-10 -4.344070  12375.000000
#
#     Total-YOY-NK     YOY-NK  YTD-YOY-NK     MOM-NK  Thặng dự tháng  \
# 0  380763.672762  19.233183   16.670573   7.157091      523.982268
# 1  140113.589138  27.746998   19.450551  13.126010    -3316.502641
# 2  240650.083624  14.162479   15.110793   3.516968     3840.484909
# 3  345622.247848   9.811321   16.371327  -2.778549     1066.773009
# 4  126055.986808  15.202351   18.540790  -2.388506    -2524.878821
#
#    Thặng dự từ đầu năm  Kim ngạch xnk tháng  Kim ngạch xnk từ đầu năm  \
# 0         24768.067847         70533.996098             786295.413371
# 1        -25520.504358         24682.184873             254706.673918
# 2         50288.572205         45851.811225             531588.739453
# 3         24312.441773         66400.773009             715556.937469
# 4        -22172.809084         22225.121179             229939.164532
#
#   PreYearMonth
# 0      2023-12
# 1      2023-12
# 2      2023-12
# 3      2023-11
# 4      2023-11

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - MOM"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
# merge_df["Thặng dự từ đầu năm - MOM"] = (
#     100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
# )
merge_df["Kim ngạch xnk tháng - MOM"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
# merge_df["Kim ngạch xnk từ đầu năm - MOM"] = (
#     100
#     * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
#     - 100
# )

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM'],
#       dtype='object')

# %%
merge_df = pd.merge(
    left=xnk_merge,
    right=xnk_merge,
    left_on=["Ngành", "PreYearMonth"],
    right_on=["Ngành", "Month"],
    how="left",
)

merge_df["Thặng dự tháng - YOY"] = (
    100 * (merge_df["Thặng dự tháng_x"] / merge_df["Thặng dự tháng_y"]) - 100
)
merge_df["Thặng dự từ đầu năm - YOY"] = (
    100 * (merge_df["Thặng dự từ đầu năm_x"] / merge_df["Thặng dự từ đầu năm_y"]) - 100
)
merge_df["Kim ngạch xnk tháng - YOY"] = (
    100 * (merge_df["Kim ngạch xnk tháng_x"] / merge_df["Kim ngạch xnk tháng_y"]) - 100
)
merge_df["Kim ngạch xnk từ đầu năm - YOY"] = (
    100
    * (merge_df["Kim ngạch xnk từ đầu năm_x"] / merge_df["Kim ngạch xnk từ đầu năm_y"])
    - 100
)

merge_df = merge_df.drop(
    columns=[
        "Total-M-XK_y",
        "Total-YOY-XK_y",
        "YOY-XK_y",
        "YTD-YOY-XK_y",
        "Date_y",
        "Month_y",
        "PreMonth_y",
        "MOM-XK_y",
        "Total-M-NK_y",
        "Total-YOY-NK_y",
        "YOY-NK_y",
        "YTD-YOY-NK_y",
        "MOM-NK_y",
        "Thặng dự tháng_y",
        "Thặng dự từ đầu năm_y",
        "Kim ngạch xnk tháng_y",
        "Kim ngạch xnk từ đầu năm_y",
        "PreYearMonth_y",
        "Thặng dự tháng - MOM_y",
        "Kim ngạch xnk tháng - MOM_y",
    ]
)
merge_df = merge_df.rename(
    columns={
        "Total-M-XK_x": "Total-M-XK",
        "Total-YOY-XK_x": "Total-YOY-XK",
        "YOY-XK_x": "YOY-XK",
        "YTD-YOY-XK_x": "YTD-YOY-XK",
        "Date_x": "Date",
        "Month_x": "Month",
        "PreMonth_x": "PreMonth",
        "MOM-XK_x": "MOM-XK",
        "Total-M-NK_x": "Total-M-NK",
        "Total-YOY-NK_x": "Total-YOY-NK",
        "YOY-NK_x": "YOY-NK",
        "YTD-YOY-NK_x": "YTD-YOY-NK",
        "MOM-NK_x": "MOM-NK",
        "Thặng dự tháng_x": "Thặng dự tháng",
        "Thặng dự từ đầu năm_x": "Thặng dự từ đầu năm",
        "Kim ngạch xnk tháng_x": "Kim ngạch xnk tháng",
        "Kim ngạch xnk từ đầu năm_x": "Kim ngạch xnk từ đầu năm",
        "PreYearMonth_x": "PreYearMonth",
        "Thặng dự tháng - MOM_x": "Thặng dự tháng - MOM",
        "Kim ngạch xnk tháng - MOM_x": "Kim ngạch xnk tháng - MOM",
    }
)
xnk_merge = merge_df
merge_df[merge_df["Ngành"] == "TỔNG TRỊ GIÁ"].columns
# Out:
# Index(['Ngành', 'Total-M-XK', 'Total-YOY-XK', 'YOY-XK', 'YTD-YOY-XK', 'Date',
#        'Month', 'PreMonth', 'MOM-XK', 'Total-M-NK', 'Total-YOY-NK', 'YOY-NK',
#        'YTD-YOY-NK', 'MOM-NK', 'Thặng dự tháng', 'Thặng dự từ đầu năm',
#        'Kim ngạch xnk tháng', 'Kim ngạch xnk từ đầu năm', 'PreYearMonth',
#        'Thặng dự tháng - MOM', 'Kim ngạch xnk tháng - MOM',
#        'Thặng dự tháng - YOY', 'Thặng dự từ đầu năm - YOY',
#        'Kim ngạch xnk tháng - YOY', 'Kim ngạch xnk từ đầu năm - YOY'],
#       dtype='object')

# %%
xnk_merge.to_csv("../csv/xnk.csv")
